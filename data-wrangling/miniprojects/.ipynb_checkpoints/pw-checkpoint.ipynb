# %%
# %logstop
# %logstart -rtq ~/.logs/pw.py append
# %matplotlib inline
import matplotlib
import seaborn as sns
sns.set()
matplotlib.rcParams['figure.dpi'] = 144

# %%
from static_grader import grader

# %% [markdown]
# # PW Miniproject
# ## Introduction
#
# The objective of this miniproject is to exercise your ability to use basic Python data structures, define functions, and control program flow. We will be using these concepts to perform some fundamental data wrangling tasks such as joining data sets together, splitting data into groups, and aggregating data into summary statistics.
# **Please do not use `pandas` or `numpy` to answer these questions.**
#
# We will be working with medical data from the British NHS on prescription drugs. Since this is real data, it contains many ambiguities that we will need to confront in our analysis. This is commonplace in data science, and is one of the lessons you will learn in this miniproject.

# %% [markdown]
# ## Downloading the data
#
# We first need to download the data we'll be using from Amazon S3:

# %%
# %%bash
# mkdir pw-data
# wget http://dataincubator-wqu.s3.amazonaws.com/pwdata/201701scripts_sample.json.gz -nc -P ./pw-data
# wget http://dataincubator-wqu.s3.amazonaws.com/pwdata/practices.json.gz -nc -P ./pw-data
# Out:
# mkdir: cannot create directory ‘pw-data’: File exists
# File ‘./pw-data/201701scripts_sample.json.gz’ already there; not retrieving.
#
# File ‘./pw-data/practices.json.gz’ already there; not retrieving.

# %% [markdown]
# ## Loading the data
#
# The first step of the project is to read in the data. We will discuss reading and writing various kinds of files later in the course, but the code below should get you started.

# %%
import gzip
import simplejson as json

# %%
with gzip.open('./pw-data/201701scripts_sample.json.gz', 'rb') as f:
    scripts = json.load(f)

with gzip.open('./pw-data/practices.json.gz', 'rb') as f:
    practices = json.load(f)

# %% [markdown]
# This data set comes from Britain's National Health Service. The `scripts` variable is a list of prescriptions issued by NHS doctors. Each prescription is represented by a dictionary with various data fields: `'practice'`, `'bnf_code'`, `'bnf_name'`, `'quantity'`, `'items'`, `'nic'`, and `'act_cost'`.

# %%
scripts[:2]
# Out:
# [{'bnf_code': '0101010G0AAABAB',
#   'items': 2,
#   'practice': 'N81013',
#   'bnf_name': 'Co-Magaldrox_Susp 195mg/220mg/5ml S/F',
#   'nic': 5.98,
#   'act_cost': 5.56,
#   'quantity': 1000},
#  {'bnf_code': '0101021B0AAAHAH',
#   'items': 1,
#   'practice': 'N81013',
#   'bnf_name': 'Alginate_Raft-Forming Oral Susp S/F',
#   'nic': 1.95,
#   'act_cost': 1.82,
#   'quantity': 500}]

# %% [markdown]
# A [glossary of terms](http://webarchive.nationalarchives.gov.uk/20180328130852tf_/http://content.digital.nhs.uk/media/10686/Download-glossary-of-terms-for-GP-prescribing---presentation-level/pdf/PLP_Presentation_Level_Glossary_April_2015.pdf/) and [FAQ](http://webarchive.nationalarchives.gov.uk/20180328130852tf_/http://content.digital.nhs.uk/media/10048/FAQs-Practice-Level-Prescribingpdf/pdf/PLP_FAQs_April_2015.pdf/) is available from the NHS regarding the data. Below we supply a data dictionary briefly describing what these fields mean.
#
# | Data field |Description|
# |:----------:|-----------|
# |`'practice'`|Code designating the medical practice issuing the prescription|
# |`'bnf_code'`|British National Formulary drug code|
# |`'bnf_name'`|British National Formulary drug name|
# |`'quantity'`|Number of capsules/quantity of liquid/grams of powder prescribed|
# | `'items'`  |Number of refills (e.g. if `'quantity'` is 30 capsules, 3 `'items'` means 3 bottles of 30 capsules)|
# |  `'nic'`   |Net ingredient cost|
# |`'act_cost'`|Total cost including containers, fees, and discounts|

# %% [markdown]
# The `practices` variable is a list of member medical practices of the NHS. Each practice is represented by a dictionary containing identifying information for the medical practice. Most of the data fields are self-explanatory. Notice the values in the `'code'` field of `practices` match the values in the `'practice'` field of `scripts`.

# %%
practices[:2]
# Out:
# [{'code': 'A81001',
#   'name': 'THE DENSHAM SURGERY',
#   'addr_1': 'THE HEALTH CENTRE',
#   'addr_2': 'LAWSON STREET',
#   'borough': 'STOCKTON ON TEES',
#   'village': 'CLEVELAND',
#   'post_code': 'TS18 1HU'},
#  {'code': 'A81002',
#   'name': 'QUEENS PARK MEDICAL CENTRE',
#   'addr_1': 'QUEENS PARK MEDICAL CTR',
#   'addr_2': 'FARRER STREET',
#   'borough': 'STOCKTON ON TEES',
#   'village': 'CLEVELAND',
#   'post_code': 'TS18 2AW'}]

# %% [markdown]
# In the following questions we will ask you to explore this data set. You may need to combine pieces of the data set together in order to answer some questions. Not every element of the data set will be used in answering the questions.

# %% [markdown]
# ## Question 1: summary_statistics
#
# Our beneficiary data (`scripts`) contains quantitative data on the number of items dispensed (`'items'`), the total quantity of item dispensed (`'quantity'`), the net cost of the ingredients (`'nic'`), and the actual cost to the patient (`'act_cost'`). Whenever working with a new data set, it can be useful to calculate summary statistics to develop a feeling for the volume and character of the data. This makes it easier to spot trends and significant features during further stages of analysis.
#
# Calculate the sum, mean, standard deviation, and quartile statistics for each of these quantities. Format your results for each quantity as a list: `[sum, mean, standard deviation, 1st quartile, median, 3rd quartile]`. We'll create a `tuple` with these lists for each quantity as a final result.

# %%
import statistics

def describe(key):
    arr = [d[key] for d in scripts]
    sorted_arr = sorted(arr)
    total = sum(arr)
    avg = total / len(arr)
    s = statistics.stdev(sorted_arr)
    
    q25 = sorted_arr[round(0.25 * len(arr))]
    med = statistics.median(arr)
    q75 = sorted_arr[round(0.75 * len(arr))]

    return (total, avg, s, q25, med, q75)

# %%
summary = [('items', describe('items')),
           ('quantity', describe('quantity')),
           ('nic', describe('nic')),
           ('act_cost', describe('act_cost'))]

# %%
grader.score.pw__summary_statistics(summary)
# Out:
# ==================
# Your score:  1.0
# ==================

# %% [markdown]
# ## Question 2: most_common_item
#
# Often we are not interested only in how the data is distributed in our entire data set, but within particular groups -- for example, how many items of each drug (i.e. `'bnf_name'`) were prescribed? Calculate the total items prescribed for each `'bnf_name'`. What is the most commonly prescribed `'bnf_name'` in our data?
#
# To calculate this, we first need to split our data set into groups corresponding with the different values of `'bnf_name'`. Then we can sum the number of items dispensed within in each group. Finally we can find the largest sum.
#
# We'll use `'bnf_name'` to construct our groups. You should have *5619* unique values for `'bnf_name'`.

# %%
bnf_names = set([d['bnf_name'] for d in scripts])
assert(len(bnf_names) == 5619)

# %% [markdown]
# We want to construct "groups" identified by `'bnf_name'`, where each group is a collection of prescriptions (i.e. dictionaries from `scripts`). We'll construct a dictionary called `groups`, using `bnf_names` as the keys. We'll represent a group with a `list`, since we can easily append new members to the group. To split our `scripts` into groups by `'bnf_name'`, we should iterate over `scripts`, appending prescription dictionaries to each group as we encounter them.

# %%
groups = {name: [] for name in bnf_names}
for script in scripts:
    # INSERT ...
    groups[script['bnf_name']].append(script['items'])

# %%
my_dict = {}
for group in groups:
    sum_value = sum(groups[group])
    my_dict[group] = sum_value

# %%
key_value = max(my_dict, key=my_dict.get)
dict_value = my_dict[key_value]

# %% [markdown]
# Now that we've constructed our groups we should sum up `'items'` in each group and find the `'bnf_name'` with the largest sum. The result, `max_item`, should have the form `[(bnf_name, item total)]`, e.g. `[('Foobar', 2000)]`.

# %%
max_item = [(key_value, dict_value)]

# %% [markdown]
# **TIP:** If you are getting an error from the grader below, please make sure your answer conforms to the correct format of `[(bnf_name, item total)]`.

# %%
grader.score.pw__most_common_item(max_item)
# Out:
# ==================
# Your score:  1.0
# ==================

# %% [markdown]
# **Challenge:** Write a function that constructs groups as we did above. The function should accept a list of dictionaries (e.g. `scripts` or `practices`) and a tuple of fields to `groupby` (e.g. `('bnf_name')` or `('bnf_name', 'post_code')`) and returns a dictionary of groups. The following questions will require you to aggregate data in groups, so this could be a useful function for the rest of the miniproject.

# %%
def group_by_field(data, fields):
    names = {tuple(item[field] for field in fields) for item in data}
    groups = {name: [] for name in names}
    for item in data:
        name = tuple(item[field] for field in fields)
        groups[name].append(item)
        
    return groups

# %%
groups = group_by_field(scripts, ('bnf_name',))
test_max_item = ...

assert test_max_item == max_item
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-19-f139006cdbad> in <module>()
#       2 test_max_item = ...
#       3
# ----> 4 assert test_max_item == max_item
#
# AssertionError:

# %% [markdown]
# ## Question 3: postal_totals
#
# Our data set is broken up among different files. This is typical for tabular data to reduce redundancy. Each table typically contains data about a particular type of event, processes, or physical object. Data on prescriptions and medical practices are in separate files in our case. If we want to find the total items prescribed in each postal code, we will have to _join_ our prescription data (`scripts`) to our clinic data (`practices`).
#
# Find the total items prescribed in each postal code, representing the results as a list of tuples `(post code, total items prescribed)`. Sort your results ascending alphabetically by post code and take only results from the first 100 post codes. Only include post codes if there is at least one prescription from a practice in that post code.
#
# **NOTE:** Some practices have multiple postal codes associated with them. Use the alphabetically first postal code.

# %% [markdown]
# We can join `scripts` and `practices` based on the fact that `'practice'` in `scripts` matches `'code'` in `practices`. However, we must first deal with the repeated values of `'code'` in `practices`. We want the alphabetically first postal codes.

# %%
practice_postal = {}
for practice in practices:
    if practice['code'] in practice_postal:
        practice_postal[practice['code']] = min(practice['post_code'],practice_postal[practice['code']])
    else:
        practice_postal[practice['code']] = practice['post_code']

# %% [markdown]
# **Challenge:** This is an aggregation of the practice data grouped by practice codes. Write an alternative implementation of the above cell using the `group_by_field` function you defined previously.

# %%
assert practice_postal['K82019'] == 'HP21 8TR'

# %% [markdown]
# Now we can join `practice_postal` to `scripts`.

# %%
joined = scripts[:]
for script in joined:
    script['post_code'] = practice_postal[script['practice']]

# %% [markdown]
# Finally we'll group the prescription dictionaries in `joined` by `'post_code'` and sum up the items prescribed in each group, as we did in the previous question.

# %%
items_by_post = ...

# %%
pc_grouped = list(group_by_field(joined, ('post_code',)).items())

# %%
items_by_post = [(pc[0], sum(group['items'] for group in groups)) for pc, groups in pc_grouped]
items_by_post=sorted(items_by_post)

# %%
items_by_post
# Out:
# [('B11 4BW', 20673),
#  ('B18 7AL', 19001),
#  ('B21 9RY', 29103),
#  ('B23 6DJ', 24859),
#  ('B70 7AW', 36531),
#  ('BB11 2DL', 34356),
#  ('BB2 1AX', 28254),
#  ('BB3 1PY', 54514),
#  ('BB4 5SL', 29388),
#  ('BB7 2JG', 44585),
#  ('BB8 0JZ', 54380),
#  ('BB9 7SR', 38224),
#  ('BD3 8QH', 21010),
#  ('BH18 8EE', 39413),
#  ('BH23 3AF', 32545),
#  ('BL1 8TU', 26132),
#  ('BL3 5HP', 27147),
#  ('BL9 0NJ', 32062),
#  ('BL9 0SN', 35275),
#  ('CB9 8HF', 51337),
#  ('CH1 4DS', 34915),
#  ('CH65 6TG', 25090),
#  ('CT11 8AD', 44358),
#  ('CV1 4FS', 37210),
#  ('CW1 3AW', 64104),
#  ('CW5 5NX', 38797),
#  ('CW7 1AT', 43164),
#  ('DA1 2HA', 26075),
#  ('DA11 8BZ', 24090),
#  ('DN22 7XF', 43091),
#  ('DN34 4GB', 48013),
#  ('FY2 0JG', 69118),
#  ('FY4 1TJ', 62886),
#  ('FY5 2TZ', 44258),
#  ('FY7 8GU', 34473),
#  ('GL1 3PX', 38120),
#  ('GL50 4DP', 74822),
#  ('GU9 9QS', 32131),
#  ('HA0 4UZ', 22755),
#  ('HA3 7LT', 32113),
#  ('HG1 5AR', 32684),
#  ('HU7 4DW', 49107),
#  ('KT14 6DH', 26758),
#  ('KT6 6EZ', 38975),
#  ('L31 0DJ', 32065),
#  ('L36 7XY', 22965),
#  ('L5 0QW', 24676),
#  ('L7 6HD', 42569),
#  ('LA1 1PN', 47335),
#  ('LE10 1DS', 49335),
#  ('LE18 2EW', 37144),
#  ('LE5 3GH', 28654),
#  ('LN2 2JP', 46173),
#  ('LS9 9EF', 48051),
#  ('M11 4EJ', 23166),
#  ('M26 2SP', 37718),
#  ('M30 0NU', 25597),
#  ('M35 0AD', 37632),
#  ('ME8 8AA', 25257),
#  ('N9 7HD', 30706),
#  ('NE10 9QG', 39882),
#  ('NE24 1DX', 50491),
#  ('NE37 2PU', 57500),
#  ('NE38 7NQ', 52803),
#  ('NG7 3GW', 17698),
#  ('NG7 5HY', 24903),
#  ('NN16 8DN', 50771),
#  ('NW10 8RY', 21553),
#  ('OL1 1NL', 41046),
#  ('OL11 1DN', 21567),
#  ('OL4 1YN', 24687),
#  ('OL9 7AY', 28394),
#  ('PL7 1AD', 65051),
#  ('RM3 9SU', 25476),
#  ('S63 9EH', 34787),
#  ('S65 1DA', 71683),
#  ('S74 9AF', 55305),
#  ('SE1 6JP', 45030),
#  ('SE15 5LJ', 15258),
#  ('SK11 6JL', 110071),
#  ('SK6 1ND', 28313),
#  ('SM3 8EP', 24965),
#  ('SM6 0HY', 46016),
#  ('SR4 7XF', 49843),
#  ('SR5 2LT', 44895),
#  ('SS0 7AF', 21569),
#  ('SS13 3HQ', 38513),
#  ('SS8 0JA', 45848),
#  ('SS9 5UU', 26095),
#  ('ST1 4PB', 24227),
#  ('ST3 6AB', 38705),
#  ('ST8 6AG', 34516),
#  ('TN24 0GP', 16955),
#  ('TN34 1BA', 47440),
#  ('TR1 2JA', 40194),
#  ('TS1 2NX', 47623),
#  ('TS10 4NW', 45161),
#  ('TS17 0EE', 68388),
#  ('TS23 2DG', 31646),
#  ('TS24 7PW', 58207),
#  ('TS3 6AL', 51402),
#  ('TW13 4GU', 19584),
#  ('TW3 3LN', 40141),
#  ('TW8 8DS', 26941),
#  ('W10 6DZ', 16264),
#  ('WA10 2DJ', 40394),
#  ('WA7 1AB', 41314),
#  ('WA9 1LN', 29644),
#  ('WD18 0JP', 21034),
#  ('WF13 1HN', 25456),
#  ('WN2 5NG', 22795),
#  ('WN3 5HL', 31149),
#  ('WN7 1HR', 29076),
#  ('WN7 2PE', 23130),
#  ('WS10 8SY', 12598),
#  ('WS3 3JP', 35242),
#  ('WV13 2DR', 33844),
#  ('YO16 4LZ', 52032)]

# %%
pc_grouped[:10]
# Out:
# [(('TS17 0EE',),
#   [{'bnf_code': '0101010G0AAABAB',
#     'items': 6,
#     'practice': 'A81017',
#     'bnf_name': 'Co-Magaldrox_Susp 195mg/220mg/5ml S/F',
#     'nic': 20.93,
#     'act_cost': 19.45,
#     'quantity': 3500,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0101021B0AAAHAH',
#     'items': 7,
#     'practice': 'A81017',
#     'bnf_name': 'Alginate_Raft-Forming Oral Susp S/F',
#     'nic': 21.04,
#     'act_cost': 19.57,
#     'quantity': 3050,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0101021B0AAALAL',
#     'items': 7,
#     'practice': 'A81017',
#     'bnf_name': 'Sod Algin/Pot Bicarb_Susp S/F',
#     'nic': 45.26,
#     'act_cost': 42.17,
#     'quantity': 4420,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0101021B0BEACAH',
#     'items': 3,
#     'practice': 'A81017',
#     'bnf_name': 'Gaviscon_Liq Orig Aniseed Relief',
#     'nic': 15.57,
#     'act_cost': 14.45,
#     'quantity': 1050,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0101021B0BEADAJ',
#     'items': 20,
#     'practice': 'A81017',
#     'bnf_name': 'Gaviscon Infant_Sach 2g (Dual Pack) S/F',
#     'nic': 260.28,
#     'act_cost': 241.2,
#     'quantity': 810,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0101021B0BEAFAH',
#     'items': 10,
#     'practice': 'A81017',
#     'bnf_name': 'Gaviscon_Liq Relief Peppermint',
#     'nic': 40.64,
#     'act_cost': 37.94,
#     'quantity': 2700,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0101021B0BEAIAL',
#     'items': 29,
#     'practice': 'A81017',
#     'bnf_name': 'Gaviscon Advance_Liq (Aniseed) (Reckitt)',
#     'nic': 179.87,
#     'act_cost': 167.56,
#     'quantity': 12940,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0101021B0BEANAH',
#     'items': 4,
#     'practice': 'A81017',
#     'bnf_name': 'Gaviscon Cool_Liq (Peppermint) S/F',
#     'nic': 15.61,
#     'act_cost': 14.6,
#     'quantity': 1050,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0101021B0BEAQAP',
#     'items': 10,
#     'practice': 'A81017',
#     'bnf_name': 'Gaviscon Advance_Tab Chble Mint(Reckitt)',
#     'nic': 55.79,
#     'act_cost': 51.87,
#     'quantity': 640,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0101021B0BEASA0',
#     'items': 1,
#     'practice': 'A81017',
#     'bnf_name': 'Gaviscon Double Action_Liq (Peppermint)',
#     'nic': 5.11,
#     'act_cost': 4.74,
#     'quantity': 300,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0101021B0BEAUA0',
#     'items': 1,
#     'practice': 'A81017',
#     'bnf_name': 'Gaviscon P/Mint_Tab Chble',
#     'nic': 2.78,
#     'act_cost': 2.59,
#     'quantity': 32,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0101021B0BEBEAL',
#     'items': 51,
#     'practice': 'A81017',
#     'bnf_name': 'Gaviscon Advance_Liq (Peppermint) S/F',
#     'nic': 309.76,
#     'act_cost': 287.96,
#     'quantity': 25080,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0101021B0BIAAAH',
#     'items': 9,
#     'practice': 'A81017',
#     'bnf_name': 'Peptac_Liq (Aniseed) S/F',
#     'nic': 18.14,
#     'act_cost': 17.02,
#     'quantity': 4650,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0101021B0BIABAH',
#     'items': 9,
#     'practice': 'A81017',
#     'bnf_name': 'Peptac_Liq (Peppermint) S/F',
#     'nic': 17.75,
#     'act_cost': 16.76,
#     'quantity': 4550,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0102000A0AAAAAA',
#     'items': 6,
#     'practice': 'A81017',
#     'bnf_name': 'Alverine Cit_Cap 60mg',
#     'nic': 107.52,
#     'act_cost': 99.93,
#     'quantity': 552,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0102000J0AAABAB',
#     'items': 2,
#     'practice': 'A81017',
#     'bnf_name': 'Dicycloverine HCl_Tab 10mg',
#     'nic': 515.9,
#     'act_cost': 477.72,
#     'quantity': 280,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0102000N0AAAAAA',
#     'items': 3,
#     'practice': 'A81017',
#     'bnf_name': 'Hyoscine Butylbrom_Inj 20mg/ml 1ml Amp',
#     'nic': 5.84,
#     'act_cost': 5.64,
#     'quantity': 20,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0102000N0AAABAB',
#     'items': 72,
#     'practice': 'A81017',
#     'bnf_name': 'Hyoscine Butylbrom_Tab 10mg',
#     'nic': 337.34,
#     'act_cost': 314.95,
#     'quantity': 6297,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0102000N0BBAAAB',
#     'items': 1,
#     'practice': 'A81017',
#     'bnf_name': 'Buscopan_Tab 10mg',
#     'nic': 6.0,
#     'act_cost': 5.57,
#     'quantity': 112,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0102000P0AAABAB',
#     'items': 89,
#     'practice': 'A81017',
#     'bnf_name': 'Mebeverine HCl_Tab 135mg',
#     'nic': 370.58,
#     'act_cost': 352.54,
#     'quantity': 7046,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0102000P0BCABAB',
#     'items': 3,
#     'practice': 'A81017',
#     'bnf_name': 'Colofac_Tab 135mg',
#     'nic': 22.74,
#     'act_cost': 21.39,
#     'quantity': 252,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0102000T0AAAAAA',
#     'items': 14,
#     'practice': 'A81017',
#     'bnf_name': 'Peppermint Oil_Cap E/C 0.2ml',
#     'nic': 103.25,
#     'act_cost': 95.86,
#     'quantity': 1232,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0102000T0AAAFAF',
#     'items': 4,
#     'practice': 'A81017',
#     'bnf_name': 'Peppermint Oil_Cap E/C 0.2ml M/R',
#     'nic': 44.82,
#     'act_cost': 41.74,
#     'quantity': 368,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0102000T0BBAAAF',
#     'items': 5,
#     'practice': 'A81017',
#     'bnf_name': 'Colpermin_Cap E/C 0.2ml M/R',
#     'nic': 54.08,
#     'act_cost': 50.62,
#     'quantity': 444,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0102000T0BCAAAA',
#     'items': 1,
#     'practice': 'A81017',
#     'bnf_name': 'Mintec_Cap E/C 0.2ml',
#     'nic': 7.04,
#     'act_cost': 6.53,
#     'quantity': 84,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0103010D0AAABAB',
#     'items': 1,
#     'practice': 'A81017',
#     'bnf_name': 'Cimetidine_Tab 400mg',
#     'nic': 15.31,
#     'act_cost': 14.19,
#     'quantity': 60,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0103010T0AAAAAA',
#     'items': 109,
#     'practice': 'A81017',
#     'bnf_name': 'Ranitidine HCl_Tab 150mg',
#     'nic': 120.56,
#     'act_cost': 121.85,
#     'quantity': 5826,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0103010T0AAACAC',
#     'items': 18,
#     'practice': 'A81017',
#     'bnf_name': 'Ranitidine HCl_Tab 300mg',
#     'nic': 23.71,
#     'act_cost': 23.36,
#     'quantity': 559,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0103010T0AAAEAE',
#     'items': 10,
#     'practice': 'A81017',
#     'bnf_name': 'Ranitidine HCl_Oral Soln 75mg/5ml S/F',
#     'nic': 87.77,
#     'act_cost': 81.88,
#     'quantity': 2960,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0103030S0AAAAAA',
#     'items': 1,
#     'practice': 'A81017',
#     'bnf_name': 'Sucralfate_Tab 1g',
#     'nic': 14.25,
#     'act_cost': 13.3,
#     'quantity': 112,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0103050E0AAAAAA',
#     'items': 20,
#     'practice': 'A81017',
#     'bnf_name': 'Esomeprazole_Tab E/C 20mg',
#     'nic': 60.94,
#     'act_cost': 57.08,
#     'quantity': 644,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0103050E0AAABAB',
#     'items': 12,
#     'practice': 'A81017',
#     'bnf_name': 'Esomeprazole_Tab E/C 40mg',
#     'nic': 100.03,
#     'act_cost': 92.74,
#     'quantity': 476,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0103050E0AAAFAF',
#     'items': 7,
#     'practice': 'A81017',
#     'bnf_name': 'Esomeprazole_Cap E/C 20mg',
#     'nic': 20.4,
#     'act_cost': 19.38,
#     'quantity': 168,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0103050E0AAAGAG',
#     'items': 12,
#     'practice': 'A81017',
#     'bnf_name': 'Esomeprazole_Cap E/C 40mg',
#     'nic': 63.36,
#     'act_cost': 58.81,
#     'quantity': 448,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0103050L0AAAAAA',
#     'items': 749,
#     'practice': 'A81017',
#     'bnf_name': 'Lansoprazole_Cap 30mg (E/C Gran)',
#     'nic': 879.94,
#     'act_cost': 833.0,
#     'quantity': 22190,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0103050L0AAABAB',
#     'items': 389,
#     'practice': 'A81017',
#     'bnf_name': 'Lansoprazole_Cap 15mg (E/C Gran)',
#     'nic': 332.38,
#     'act_cost': 318.53,
#     'quantity': 11012,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0103050L0AAAGAG',
#     'items': 5,
#     'practice': 'A81017',
#     'bnf_name': 'Lansoprazole_Orodisper Tab 15mg',
#     'nic': 12.6,
#     'act_cost': 11.74,
#     'quantity': 168,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0103050L0AAAHAH',
#     'items': 14,
#     'practice': 'A81017',
#     'bnf_name': 'Lansoprazole_Orodisper Tab 30mg',
#     'nic': 51.3,
#     'act_cost': 47.67,
#     'quantity': 420,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0103050P0AAAAAA',
#     'items': 470,
#     'practice': 'A81017',
#     'bnf_name': 'Omeprazole_Cap E/C 20mg',
#     'nic': 548.56,
#     'act_cost': 518.92,
#     'quantity': 16899,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0103050P0AAAFAF',
#     'items': 26,
#     'practice': 'A81017',
#     'bnf_name': 'Omeprazole_Cap E/C 10mg',
#     'nic': 26.7,
#     'act_cost': 25.04,
#     'quantity': 840,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0103050P0AAAMAM',
#     'items': 3,
#     'practice': 'A81017',
#     'bnf_name': 'Omeprazole_Tab Disper 10mg (E/C Pellets)',
#     'nic': 23.25,
#     'act_cost': 21.57,
#     'quantity': 84,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0103050P0AAANAN',
#     'items': 7,
#     'practice': 'A81017',
#     'bnf_name': 'Omeprazole_Tab Disper 20mg (E/C Pellets)',
#     'nic': 92.8,
#     'act_cost': 85.99,
#     'quantity': 224,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0103050P0AABDBD',
#     'items': 1,
#     'practice': 'A81017',
#     'bnf_name': 'Omeprazole_Tab E/C 20mg',
#     'nic': 12.02,
#     'act_cost': 11.14,
#     'quantity': 56,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0103050P0AABLBL',
#     'items': 5,
#     'practice': 'A81017',
#     'bnf_name': 'Omeprazole_Oral Susp 10mg/5ml',
#     'nic': 365.4,
#     'act_cost': 338.33,
#     'quantity': 475,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0103050P0AABNBN',
#     'items': 1,
#     'practice': 'A81017',
#     'bnf_name': 'Omeprazole_Oral Susp 5mg/5ml',
#     'nic': 75.64,
#     'act_cost': 70.04,
#     'quantity': 140,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0103050P0BBAAAA',
#     'items': 1,
#     'practice': 'A81017',
#     'bnf_name': 'Losec_Cap E/C 20mg',
#     'nic': 13.92,
#     'act_cost': 12.9,
#     'quantity': 28,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0103050R0AAAAAA',
#     'items': 8,
#     'practice': 'A81017',
#     'bnf_name': 'Pantoprazole_Tab E/C 40mg',
#     'nic': 11.2,
#     'act_cost': 10.48,
#     'quantity': 280,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0103050R0AAABAB',
#     'items': 17,
#     'practice': 'A81017',
#     'bnf_name': 'Pantoprazole_Tab E/C 20mg',
#     'nic': 13.79,
#     'act_cost': 13.55,
#     'quantity': 406,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0103050T0AAABAB',
#     'items': 6,
#     'practice': 'A81017',
#     'bnf_name': 'Rabeprazole Sod_Tab E/C 20mg',
#     'nic': 10.75,
#     'act_cost': 10.02,
#     'quantity': 168,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0104020L0AAAAAA',
#     'items': 46,
#     'practice': 'A81017',
#     'bnf_name': 'Loperamide HCl_Cap 2mg',
#     'nic': 110.84,
#     'act_cost': 106.1,
#     'quantity': 3462,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0104020L0AAABAB',
#     'items': 1,
#     'practice': 'A81017',
#     'bnf_name': 'Loperamide HCl_Oral Soln 1mg/5ml S/F',
#     'nic': 3.51,
#     'act_cost': 3.26,
#     'quantity': 300,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0104020L0AAADAD',
#     'items': 1,
#     'practice': 'A81017',
#     'bnf_name': 'Loperamide HCl_Tab 2mg',
#     'nic': 8.03,
#     'act_cost': 7.55,
#     'quantity': 112,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0105010B0AAAAAA',
#     'items': 6,
#     'practice': 'A81017',
#     'bnf_name': 'Mesalazine_Tab E/C 400mg',
#     'nic': 123.55,
#     'act_cost': 114.96,
#     'quantity': 378,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0105010B0BBAAAA',
#     'items': 8,
#     'practice': 'A81017',
#     'bnf_name': 'Asacol_MR Tab E/C 400mg',
#     'nic': 435.27,
#     'act_cost': 403.46,
#     'quantity': 1332,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0105010B0BBAFAS',
#     'items': 3,
#     'practice': 'A81017',
#     'bnf_name': 'Asacol_MR Tab E/C 800mg',
#     'nic': 128.1,
#     'act_cost': 118.84,
#     'quantity': 196,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0105010B0BCACAI',
#     'items': 3,
#     'practice': 'A81017',
#     'bnf_name': 'Pentasa SR_Tab 500mg',
#     'nic': 145.1,
#     'act_cost': 134.66,
#     'quantity': 472,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0105010B0BHAAAR',
#     'items': 4,
#     'practice': 'A81017',
#     'bnf_name': 'Mezavant XL_Tab G/R 1.2g',
#     'nic': 206.16,
#     'act_cost': 191.1,
#     'quantity': 288,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0105010D0AAABAB',
#     'items': 10,
#     'practice': 'A81017',
#     'bnf_name': 'Balsalazide Sod_Cap 750mg',
#     'nic': 330.4,
#     'act_cost': 306.78,
#     'quantity': 1412,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0105010E0AAAAAA',
#     'items': 10,
#     'practice': 'A81017',
#     'bnf_name': 'Sulfasalazine_Tab 500mg',
#     'nic': 64.51,
#     'act_cost': 60.36,
#     'quantity': 980,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0105010E0AAABAB',
#     'items': 27,
#     'practice': 'A81017',
#     'bnf_name': 'Sulfasalazine_Tab E/C 500mg',
#     'nic': 287.91,
#     'act_cost': 268.24,
#     'quantity': 2884,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0105010E0BBABAB',
#     'items': 5,
#     'practice': 'A81017',
#     'bnf_name': 'Salazopyrin-En_Tab 500mg',
#     'nic': 50.59,
#     'act_cost': 47.09,
#     'quantity': 672,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0106010E0AAADAD',
#     'items': 18,
#     'practice': 'A81017',
#     'bnf_name': 'Ispag Husk_Gran Eff Sach 3.5g G/F S/F',
#     'nic': 66.21,
#     'act_cost': 62.32,
#     'quantity': 730,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0106010E0AAATAT',
#     'items': 7,
#     'practice': 'A81017',
#     'bnf_name': 'Ispag Husk_Gran Sach 3.5g G/F',
#     'nic': 31.56,
#     'act_cost': 29.71,
#     'quantity': 348,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0106010E0BBAAAD',
#     'items': 2,
#     'practice': 'A81017',
#     'bnf_name': 'Fybogel_Gran Sach 3.5g Plain G/F S/F',
#     'nic': 5.44,
#     'act_cost': 5.06,
#     'quantity': 60,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0106010E0BBABAH',
#     'items': 1,
#     'practice': 'A81017',
#     'bnf_name': 'Fybogel_Gran Sach 3.5g Orange G/F S/F',
#     'nic': 5.44,
#     'act_cost': 5.05,
#     'quantity': 60,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0106010E0BKAAAH',
#     'items': 2,
#     'practice': 'A81017',
#     'bnf_name': 'Fybogel_H/Fbre Gran Eff Sach3.5g OrngS/F',
#     'nic': 23.28,
#     'act_cost': 21.67,
#     'quantity': 144,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0106020C0AAAAAA',
#     'items': 42,
#     'practice': 'A81017',
#     'bnf_name': 'Bisacodyl_Tab E/C 5mg',
#     'nic': 72.05,
#     'act_cost': 71.0,
#     'quantity': 2206,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0106020C0AAAEAE',
#     'items': 1,
#     'practice': 'A81017',
#     'bnf_name': 'Bisacodyl_Suppos 10mg',
#     'nic': 3.53,
#     'act_cost': 3.28,
#     'quantity': 12,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0106020I0AAAIAI',
#     'items': 4,
#     'practice': 'A81017',
#     'bnf_name': 'Docusate Sod_Oral Soln 50mg/5ml S/F',
#     'nic': 68.71,
#     'act_cost': 63.87,
#     'quantity': 2580,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0106020I0AAAKAK',
#     'items': 141,
#     'practice': 'A81017',
#     'bnf_name': 'Docusate Sod_Cap 100mg',
#     'nic': 710.65,
#     'act_cost': 671.53,
#     'quantity': 10202,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0106020L0AAACAC',
#     'items': 6,
#     'practice': 'A81017',
#     'bnf_name': "Glycerol_Suppos Adult's (4g)",
#     'nic': 8.5,
#     'act_cost': 8.15,
#     'quantity': 88,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0106020M0AAACAC',
#     'items': 68,
#     'practice': 'A81017',
#     'bnf_name': 'Senna_Tab 7.5mg',
#     'nic': 129.09,
#     'act_cost': 126.33,
#     'quantity': 3849,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0106020M0AAAPAP',
#     'items': 3,
#     'practice': 'A81017',
#     'bnf_name': 'Senna_Tab 15mg',
#     'nic': 7.33,
#     'act_cost': 7.13,
#     'quantity': 68,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0106020M0AAATAT',
#     'items': 84,
#     'practice': 'A81017',
#     'bnf_name': 'Senna_Oral Soln 7.5mg/5ml S/F',
#     'nic': 278.16,
#     'act_cost': 264.26,
#     'quantity': 29200,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0106020P0AAABAB',
#     'items': 8,
#     'practice': 'A81017',
#     'bnf_name': 'Sod Picosulf_Oral Soln 5mg/5ml S/F',
#     'nic': 49.7,
#     'act_cost': 46.33,
#     'quantity': 2100,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0106040G0AAAAAA',
#     'items': 99,
#     'practice': 'A81017',
#     'bnf_name': 'Lactulose_Soln 3.1g-3.7g/5ml',
#     'nic': 250.49,
#     'act_cost': 238.36,
#     'quantity': 49700,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0106040M0AAAAAA',
#     'items': 89,
#     'practice': 'A81017',
#     'bnf_name': 'Macrogol_Co Oral Pdr Sach S/F',
#     'nic': 558.5,
#     'act_cost': 521.77,
#     'quantity': 3854,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0106040M0AAABAB',
#     'items': 3,
#     'practice': 'A81017',
#     'bnf_name': 'Macrogol_Co Oral Pdr Sach H/Strgh6.9gS/F',
#     'nic': 15.06,
#     'act_cost': 14.28,
#     'quantity': 112,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0106040M0AAAHAH',
#     'items': 5,
#     'practice': 'A81017',
#     'bnf_name': 'Macrogol_Co Liq NPF S/F',
#     'nic': 52.53,
#     'act_cost': 48.8,
#     'quantity': 5100,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0106040M0BBAAAA',
#     'items': 7,
#     'practice': 'A81017',
#     'bnf_name': 'Movicol_Pdr Sach 13.8g (Lem & Lim)',
#     'nic': 92.65,
#     'act_cost': 85.87,
#     'quantity': 360,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0106040M0BBABAB',
#     'items': 4,
#     'practice': 'A81017',
#     'bnf_name': 'Movicol-Half_Pdr Sach 6.9g (Lem & Lim)',
#     'nic': 9.44,
#     'act_cost': 9.19,
#     'quantity': 56,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0106040M0BBADAA',
#     'items': 4,
#     'practice': 'A81017',
#     'bnf_name': 'Movicol Plain_Pdr Sach 13.7g',
#     'nic': 42.21,
#     'act_cost': 39.43,
#     'quantity': 164,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0106040M0BBAIAB',
#     'items': 22,
#     'practice': 'A81017',
#     'bnf_name': 'Movicol Plain_Paed Pdr Sach 6.9g',
#     'nic': 143.38,
#     'act_cost': 133.23,
#     'quantity': 982,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0106040M0BBAJAB',
#     'items': 4,
#     'practice': 'A81017',
#     'bnf_name': 'Movicol_Paed Pdr Sach 6.9g (Choc)',
#     'nic': 21.9,
#     'act_cost': 20.32,
#     'quantity': 150,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0106040M0BCACAA',
#     'items': 40,
#     'practice': 'A81017',
#     'bnf_name': 'Laxido_Oral Pdr Sach (Orange) S/F',
#     'nic': 238.34,
#     'act_cost': 223.56,
#     'quantity': 1674,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0106070A0AAABAB',
#     'items': 6,
#     'practice': 'A81017',
#     'bnf_name': 'Prucalopride_Tab 2mg',
#     'nic': 416.64,
#     'act_cost': 385.77,
#     'quantity': 196,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0107010Z0BCAAAE',
#     'items': 9,
#     'practice': 'A81017',
#     'bnf_name': 'Anusol_Crm',
#     'nic': 39.2,
#     'act_cost': 36.4,
#     'quantity': 368,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0107010Z0BCABAF',
#     'items': 3,
#     'practice': 'A81017',
#     'bnf_name': 'Anusol_Oint',
#     'nic': 12.25,
#     'act_cost': 11.38,
#     'quantity': 125,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0107020J0AAAEAE',
#     'items': 2,
#     'practice': 'A81017',
#     'bnf_name': 'Cinchocaine HCl/Hydrocort_Oint 0.5%/0.5%',
#     'nic': 20.68,
#     'act_cost': 19.16,
#     'quantity': 60,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0107020J0AAAGAG',
#     'items': 3,
#     'practice': 'A81017',
#     'bnf_name': 'Lido/Hydrocort Acet_Oint 5%/0.275%',
#     'nic': 16.76,
#     'act_cost': 15.55,
#     'quantity': 80,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0107020J0BEABAF',
#     'items': 3,
#     'practice': 'A81017',
#     'bnf_name': 'Proctosedyl_Suppos',
#     'nic': 15.24,
#     'act_cost': 14.16,
#     'quantity': 36,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0107020J0BGAAAG',
#     'items': 2,
#     'practice': 'A81017',
#     'bnf_name': 'Xyloproct_Oint 5%/0.275%',
#     'nic': 8.38,
#     'act_cost': 7.78,
#     'quantity': 40,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0107020P0AAACAC',
#     'items': 1,
#     'practice': 'A81017',
#     'bnf_name': 'Cinchocaine/Prednisolone_Oint 0.5%/0.19%',
#     'nic': 2.94,
#     'act_cost': 2.73,
#     'quantity': 30,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 4,
#     'practice': 'A81017',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 20.58,
#     'act_cost': 19.1,
#     'quantity': 210,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0107020P0BCABAD',
#     'items': 1,
#     'practice': 'A81017',
#     'bnf_name': 'Scheriproct_Suppos',
#     'nic': 1.38,
#     'act_cost': 1.29,
#     'quantity': 12,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0107040A0AAAIAI',
#     'items': 3,
#     'practice': 'A81017',
#     'bnf_name': 'Glyceryl Trinit_Oint 0.4%',
#     'nic': 117.9,
#     'act_cost': 109.18,
#     'quantity': 90,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0109010U0AAAAAA',
#     'items': 2,
#     'practice': 'A81017',
#     'bnf_name': 'Ursodeoxycholic Acid_Tab 150mg',
#     'nic': 129.34,
#     'act_cost': 119.86,
#     'quantity': 408,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0109010U0AAABAB',
#     'items': 13,
#     'practice': 'A81017',
#     'bnf_name': 'Ursodeoxycholic Acid_Cap 250mg',
#     'nic': 386.11,
#     'act_cost': 358.71,
#     'quantity': 916,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0109010U0AABKBK',
#     'items': 3,
#     'practice': 'A81017',
#     'bnf_name': 'Ursodeoxycholic Acid_Tab 500mg',
#     'nic': 89.6,
#     'act_cost': 83.29,
#     'quantity': 112,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0109040N0BDADAU',
#     'items': 11,
#     'practice': 'A81017',
#     'bnf_name': 'Creon 10000_Cap E/C',
#     'nic': 435.99,
#     'act_cost': 404.24,
#     'quantity': 3372,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0109040N0BDAFAW',
#     'items': 1,
#     'practice': 'A81017',
#     'bnf_name': 'Creon 40000_Cap E/C',
#     'nic': 41.8,
#     'act_cost': 38.71,
#     'quantity': 100,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0201010F0AAADAD',
#     'items': 11,
#     'practice': 'A81017',
#     'bnf_name': 'Digoxin_Tab 62.5mcg',
#     'nic': 20.48,
#     'act_cost': 19.21,
#     'quantity': 315,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0201010F0AAAEAE',
#     'items': 33,
#     'practice': 'A81017',
#     'bnf_name': 'Digoxin_Tab 125mcg',
#     'nic': 53.72,
#     'act_cost': 50.75,
#     'quantity': 826,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0201010F0AAAFAF',
#     'items': 15,
#     'practice': 'A81017',
#     'bnf_name': 'Digoxin_Tab 250mcg',
#     'nic': 19.69,
#     'act_cost': 19.12,
#     'quantity': 301,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0202010B0AAABAB',
#     'items': 325,
#     'practice': 'A81017',
#     'bnf_name': 'Bendroflumethiazide_Tab 2.5mg',
#     'nic': 227.29,
#     'act_cost': 216.13,
#     'quantity': 9639,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0202010B0AAACAC',
#     'items': 6,
#     'practice': 'A81017',
#     'bnf_name': 'Bendroflumethiazide_Tab 5mg',
#     'nic': 5.16,
#     'act_cost': 4.86,
#     'quantity': 168,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0202010P0AAAAAA',
#     'items': 151,
#     'practice': 'A81017',
#     'bnf_name': 'Indapamide_Tab 2.5mg',
#     'nic': 356.76,
#     'act_cost': 332.64,
#     'quantity': 4624,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0202010P0AAADAD',
#     'items': 17,
#     'practice': 'A81017',
#     'bnf_name': 'Indapamide_Tab 1.5mg M/R',
#     'nic': 63.24,
#     'act_cost': 59.16,
#     'quantity': 558,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0202020D0AAAEAE',
#     'items': 11,
#     'practice': 'A81017',
#     'bnf_name': 'Bumetanide_Tab 1mg',
#     'nic': 22.96,
#     'act_cost': 21.39,
#     'quantity': 392,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0202020L0AABBBB',
#     'items': 87,
#     'practice': 'A81017',
#     'bnf_name': 'Furosemide_Tab 20mg',
#     'nic': 62.01,
#     'act_cost': 60.78,
#     'quantity': 2380,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0202020L0AABDBD',
#     'items': 255,
#     'practice': 'A81017',
#     'bnf_name': 'Furosemide_Tab 40mg',
#     'nic': 197.03,
#     'act_cost': 192.82,
#     'quantity': 7996,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0202020L0AABNBN',
#     'items': 1,
#     'practice': 'A81017',
#     'bnf_name': 'Furosemide_Oral Soln 40mg/5ml S/F',
#     'nic': 17.44,
#     'act_cost': 16.26,
#     'quantity': 140,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0202030C0AAACAC',
#     'items': 4,
#     'practice': 'A81017',
#     'bnf_name': 'Amiloride HCl_Tab 5mg',
#     'nic': 6.05,
#     'act_cost': 5.64,
#     'quantity': 140,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0202030S0AAATAT',
#     'items': 34,
#     'practice': 'A81017',
#     'bnf_name': 'Spironol_Tab 25mg',
#     'nic': 40.0,
#     'act_cost': 38.06,
#     'quantity': 861,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0202030S0AAAUAU',
#     'items': 3,
#     'practice': 'A81017',
#     'bnf_name': 'Spironol_Tab 50mg',
#     'nic': 5.1,
#     'act_cost': 4.77,
#     'quantity': 84,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0202030S0AAAVAV',
#     'items': 12,
#     'practice': 'A81017',
#     'bnf_name': 'Spironol_Tab 100mg',
#     'nic': 38.29,
#     'act_cost': 35.8,
#     'quantity': 536,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0202030X0AAAAAA',
#     'items': 27,
#     'practice': 'A81017',
#     'bnf_name': 'Eplerenone_Tab 25mg',
#     'nic': 95.26,
#     'act_cost': 89.36,
#     'quantity': 644,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0202030X0AAABAB',
#     'items': 5,
#     'practice': 'A81017',
#     'bnf_name': 'Eplerenone_Tab 50mg',
#     'nic': 32.22,
#     'act_cost': 29.88,
#     'quantity': 168,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0202040B0AAAAAA',
#     'items': 5,
#     'practice': 'A81017',
#     'bnf_name': 'Co-Amilofruse_Tab 5mg/40mg',
#     'nic': 10.89,
#     'act_cost': 10.15,
#     'quantity': 252,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0202040B0AAABAB',
#     'items': 2,
#     'practice': 'A81017',
#     'bnf_name': 'Co-Amilofruse_Tab 2.5mg/20mg',
#     'nic': 2.4,
#     'act_cost': 2.24,
#     'quantity': 56,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0202040C0AAAAAA',
#     'items': 5,
#     'practice': 'A81017',
#     'bnf_name': 'Co-Amilozide_Tab 5mg/50mg',
#     'nic': 5.1,
#     'act_cost': 4.78,
#     'quantity': 140,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0203020D0AAABAB',
#     'items': 4,
#     'practice': 'A81017',
#     'bnf_name': 'Amiodarone HCl_Tab 200mg',
#     'nic': 7.73,
#     'act_cost': 7.21,
#     'quantity': 112,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0203020I0AAADAD',
#     'items': 1,
#     'practice': 'A81017',
#     'bnf_name': 'Flecainide Acet_Tab 100mg',
#     'nic': 12.6,
#     'act_cost': 11.78,
#     'quantity': 56,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0203020I0AAAKAK',
#     'items': 4,
#     'practice': 'A81017',
#     'bnf_name': 'Flecainide Acet_Tab 50mg',
#     'nic': 43.51,
#     'act_cost': 40.62,
#     'quantity': 232,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0204000ABAAAAAA',
#     'items': 16,
#     'practice': 'A81017',
#     'bnf_name': 'Nebivolol_Tab 5mg',
#     'nic': 18.74,
#     'act_cost': 17.96,
#     'quantity': 420,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0204000ABAAABAB',
#     'items': 1,
#     'practice': 'A81017',
#     'bnf_name': 'Nebivolol_Tab 2.5mg',
#     'nic': 31.52,
#     'act_cost': 29.19,
#     'quantity': 28,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0204000E0AAAAAA',
#     'items': 4,
#     'practice': 'A81017',
#     'bnf_name': 'Atenolol_Oral Soln 25mg/5ml S/F',
#     'nic': 22.36,
#     'act_cost': 20.75,
#     'quantity': 1200,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0204000E0AAABAB',
#     'items': 162,
#     'practice': 'A81017',
#     'bnf_name': 'Atenolol_Tab 50mg',
#     'nic': 125.83,
#     'act_cost': 119.77,
#     'quantity': 4823,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0204000E0AAACAC',
#     'items': 127,
#     'practice': 'A81017',
#     'bnf_name': 'Atenolol_Tab 100mg',
#     'nic': 96.2,
#     'act_cost': 91.12,
#     'quantity': 3591,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0204000E0AAAGAG',
#     'items': 72,
#     'practice': 'A81017',
#     'bnf_name': 'Atenolol_Tab 25mg',
#     'nic': 52.03,
#     'act_cost': 49.98,
#     'quantity': 2051,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0204000H0AAAAAA',
#     'items': 181,
#     'practice': 'A81017',
#     'bnf_name': 'Bisoprolol Fumar_Tab 5mg',
#     'nic': 165.5,
#     'act_cost': 156.85,
#     'quantity': 5362,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0204000H0AAABAB',
#     'items': 89,
#     'practice': 'A81017',
#     'bnf_name': 'Bisoprolol Fumar_Tab 10mg',
#     'nic': 63.83,
#     'act_cost': 61.7,
#     'quantity': 2261,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0204000H0AAAJAJ',
#     'items': 213,
#     'practice': 'A81017',
#     'bnf_name': 'Bisoprolol Fumar_Tab 2.5mg',
#     'nic': 164.7,
#     'act_cost': 157.92,
#     'quantity': 5908,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0204000H0AAAKAK',
#     'items': 33,
#     'practice': 'A81017',
#     'bnf_name': 'Bisoprolol Fumar_Tab 3.75mg',
#     'nic': 31.58,
#     'act_cost': 30.25,
#     'quantity': 848,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0204000H0AAALAL',
#     'items': 16,
#     'practice': 'A81017',
#     'bnf_name': 'Bisoprolol Fumar_Tab 7.5mg',
#     'nic': 69.12,
#     'act_cost': 64.17,
#     'quantity': 448,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0204000H0AAAMAM',
#     'items': 85,
#     'practice': 'A81017',
#     'bnf_name': 'Bisoprolol Fumar_Tab 1.25mg',
#     'nic': 69.9,
#     'act_cost': 67.65,
#     'quantity': 2037,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0204000I0AAACAC',
#     'items': 2,
#     'practice': 'A81017',
#     'bnf_name': 'Labetalol HCl_Tab 100mg',
#     'nic': 17.13,
#     'act_cost': 15.88,
#     'quantity': 168,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0204000I0AAADAD',
#     'items': 1,
#     'practice': 'A81017',
#     'bnf_name': 'Labetalol HCl_Tab 200mg',
#     'nic': 8.77,
#     'act_cost': 8.13,
#     'quantity': 56,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0204000K0AAABAB',
#     'items': 86,
#     'practice': 'A81017',
#     'bnf_name': 'Metoprolol Tart_Tab 50mg',
#     'nic': 135.52,
#     'act_cost': 127.96,
#     'quantity': 3613,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0204000K0AAACAC',
#     'items': 14,
#     'practice': 'A81017',
#     'bnf_name': 'Metoprolol Tart_Tab 100mg',
#     'nic': 35.1,
#     'act_cost': 32.68,
#     'quantity': 840,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0204000R0AAAAAA',
#     'items': 68,
#     'practice': 'A81017',
#     'bnf_name': 'Propranolol HCl_Cap 80mg M/R',
#     'nic': 392.31,
#     'act_cost': 364.9,
#     'quantity': 2219,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0204000R0AAABAB',
#     'items': 15,
#     'practice': 'A81017',
#     'bnf_name': 'Propranolol HCl_Cap 160mg M/R',
#     'nic': 82.96,
#     'act_cost': 76.99,
#     'quantity': 476,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0204000R0AAAHAH',
#     'items': 55,
#     'practice': 'A81017',
#     'bnf_name': 'Propranolol HCl_Tab 10mg',
#     'nic': 103.47,
#     'act_cost': 97.69,
#     'quantity': 3404,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0204000R0AAAJAJ',
#     'items': 119,
#     'practice': 'A81017',
#     'bnf_name': 'Propranolol HCl_Tab 40mg',
#     'nic': 197.42,
#     'act_cost': 185.95,
#     'quantity': 6502,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0204000R0AAAKAK',
#     'items': 5,
#     'practice': 'A81017',
#     'bnf_name': 'Propranolol HCl_Tab 80mg',
#     'nic': 10.71,
#     'act_cost': 9.99,
#     'quantity': 392,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0204000T0AAACAC',
#     'items': 2,
#     'practice': 'A81017',
#     'bnf_name': 'Sotalol HCl_Tab 80mg',
#     'nic': 4.4,
#     'act_cost': 4.1,
#     'quantity': 112,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '020400040AAAAAA',
#     'items': 8,
#     'practice': 'A81017',
#     'bnf_name': 'Co-Tenidone_Tab 50mg/12.5mg',
#     'nic': 14.43,
#     'act_cost': 13.77,
#     'quantity': 245,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0205020M0AAABAB',
#     'items': 1,
#     'practice': 'A81017',
#     'bnf_name': 'Moxonidine_Tab 400mcg',
#     'nic': 1.51,
#     'act_cost': 1.41,
#     'quantity': 28,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0205040D0AAAAAA',
#     'items': 19,
#     'practice': 'A81017',
#     'bnf_name': 'Doxazosin Mesil_Tab 1mg',
#     'nic': 19.17,
#     'act_cost': 18.0,
#     'quantity': 756,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0205040D0AAABAB',
#     'items': 71,
#     'practice': 'A81017',
#     'bnf_name': 'Doxazosin Mesil_Tab 2mg',
#     'nic': 59.98,
#     'act_cost': 57.18,
#     'quantity': 2268,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0205040D0AAACAC',
#     'items': 83,
#     'practice': 'A81017',
#     'bnf_name': 'Doxazosin Mesil_Tab 4mg',
#     'nic': 111.72,
#     'act_cost': 104.88,
#     'quantity': 3724,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0205040D0AAAQAQ',
#     'items': 17,
#     'practice': 'A81017',
#     'bnf_name': 'Doxazosin Mesil_Tab 4mg M/R',
#     'nic': 130.0,
#     'act_cost': 120.55,
#     'quantity': 728,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0205040D0AAARAR',
#     'items': 14,
#     'practice': 'A81017',
#     'bnf_name': 'Doxazosin Mesil_Tab 8mg M/R',
#     'nic': 219.56,
#     'act_cost': 203.42,
#     'quantity': 616,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0205040S0AAACAC',
#     'items': 2,
#     'practice': 'A81017',
#     'bnf_name': 'Prazosin HCl_Tab 1mg',
#     'nic': 8.07,
#     'act_cost': 7.69,
#     'quantity': 140,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0205040V0AAACAC',
#     'items': 1,
#     'practice': 'A81017',
#     'bnf_name': 'Terazosin HCl_Tab 5mg',
#     'nic': 4.2,
#     'act_cost': 3.9,
#     'quantity': 56,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0205051I0AAABAB',
#     'items': 3,
#     'practice': 'A81017',
#     'bnf_name': 'Enalapril Mal_Tab 5mg',
#     'nic': 3.36,
#     'act_cost': 3.15,
#     'quantity': 112,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0205051I0AAACAC',
#     'items': 7,
#     'practice': 'A81017',
#     'bnf_name': 'Enalapril Mal_Tab 10mg',
#     'nic': 8.1,
#     'act_cost': 7.6,
#     'quantity': 252,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0205051I0AAADAD',
#     'items': 17,
#     'practice': 'A81017',
#     'bnf_name': 'Enalapril Mal_Tab 20mg',
#     'nic': 22.54,
#     'act_cost': 21.08,
#     'quantity': 644,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0205051J0AAAAAA',
#     'items': 1,
#     'practice': 'A81017',
#     'bnf_name': 'Fosinopril Sod_Tab 10mg',
#     'nic': 7.87,
#     'act_cost': 7.3,
#     'quantity': 28,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0205051K0AAAAAA',
#     'items': 1,
#     'practice': 'A81017',
#     'bnf_name': 'Lisinopril/Hydchloroth_Tab 20mg/12.5mg',
#     'nic': 1.82,
#     'act_cost': 1.7,
#     'quantity': 28,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0205051K0AAABAB',
#     'items': 1,
#     'practice': 'A81017',
#     'bnf_name': 'Lisinopril/Hydchloroth_Tab 10mg/12.5mg',
#     'nic': 4.99,
#     'act_cost': 4.63,
#     'quantity': 28,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0205051L0AAAAAA',
#     'items': 22,
#     'practice': 'A81017',
#     'bnf_name': 'Lisinopril_Tab 2.5mg',
#     'nic': 19.31,
#     'act_cost': 18.15,
#     'quantity': 784,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0205051L0AAABAB',
#     'items': 72,
#     'practice': 'A81017',
#     'bnf_name': 'Lisinopril_Tab 5mg',
#     'nic': 59.41,
#     'act_cost': 55.89,
#     'quantity': 2324,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0205051L0AAACAC',
#     'items': 79,
#     'practice': 'A81017',
#     'bnf_name': 'Lisinopril_Tab 10mg',
#     'nic': 69.53,
#     'act_cost': 65.77,
#     'quantity': 2464,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0205051L0AAADAD',
#     'items': 67,
#     'practice': 'A81017',
#     'bnf_name': 'Lisinopril_Tab 20mg',
#     'nic': 63.91,
#     'act_cost': 60.0,
#     'quantity': 2156,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0205051M0AAAAAA',
#     'items': 21,
#     'practice': 'A81017',
#     'bnf_name': 'Perindopril Erbumine_Tab 2mg',
#     'nic': 20.61,
#     'act_cost': 20.44,
#     'quantity': 664,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0205051M0AAABAB',
#     'items': 44,
#     'practice': 'A81017',
#     'bnf_name': 'Perindopril Erbumine_Tab 4mg',
#     'nic': 50.75,
#     'act_cost': 50.0,
#     'quantity': 1396,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0205051M0AAAFAF',
#     'items': 14,
#     'practice': 'A81017',
#     'bnf_name': 'Perindopril Erbumine_Tab 8mg',
#     'nic': 22.7,
#     'act_cost': 21.79,
#     'quantity': 524,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0205051R0AAAAAA',
#     'items': 51,
#     'practice': 'A81017',
#     'bnf_name': 'Ramipril_Cap 1.25mg',
#     'nic': 42.4,
#     'act_cost': 42.67,
#     'quantity': 868,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0205051R0AAABAB',
#     'items': 210,
#     'practice': 'A81017',
#     'bnf_name': 'Ramipril_Cap 2.5mg',
#     'nic': 382.26,
#     'act_cost': 358.29,
#     'quantity': 6150,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0205051R0AAACAC',
#     'items': 224,
#     'practice': 'A81017',
#     'bnf_name': 'Ramipril_Cap 5mg',
#     'nic': 285.96,
#     'act_cost': 268.8,
#     'quantity': 6895,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0205051R0AAADAD',
#     'items': 565,
#     'practice': 'A81017',
#     'bnf_name': 'Ramipril_Cap 10mg',
#     'nic': 709.04,
#     'act_cost': 666.07,
#     'quantity': 17262,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0205051R0AAAKAK',
#     'items': 1,
#     'practice': 'A81017',
#     'bnf_name': 'Ramipril_Tab 1.25mg',
#     'nic': 1.65,
#     'act_cost': 1.54,
#     'quantity': 28,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0205051R0AAALAL',
#     'items': 20,
#     'practice': 'A81017',
#     'bnf_name': 'Ramipril_Tab 2.5mg',
#     'nic': 22.43,
#     'act_cost': 21.22,
#     'quantity': 546,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0205051R0AAAMAM',
#     'items': 53,
#     'practice': 'A81017',
#     'bnf_name': 'Ramipril_Tab 5mg',
#     'nic': 50.99,
#     'act_cost': 48.47,
#     'quantity': 1456,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0205051R0AAANAN',
#     'items': 9,
#     'practice': 'A81017',
#     'bnf_name': 'Ramipril_Tab 10mg',
#     'nic': 10.48,
#     'act_cost': 9.81,
#     'quantity': 252,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0205051Z0AAAAAA',
#     'items': 1,
#     'practice': 'A81017',
#     'bnf_name': 'Perindopril Argin/Indapam_Tab 5mg/1.25mg',
#     'nic': 19.02,
#     'act_cost': 17.62,
#     'quantity': 60,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0205052A0AAAAAA',
#     'items': 2,
#     'practice': 'A81017',
#     'bnf_name': 'Irbesartan/Hydchloroth_Tab 150mg/12.5mg',
#     'nic': 9.3,
#     'act_cost': 8.64,
#     'quantity': 56,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0205052B0AAABAB',
#     'items': 3,
#     'practice': 'A81017',
#     'bnf_name': 'Olmesartan Medoxomil_Tab 20mg',
#     'nic': 38.85,
#     'act_cost': 36.0,
#     'quantity': 84,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0205052B0AAACAC',
#     'items': 5,
#     'practice': 'A81017',
#     'bnf_name': 'Olmesartan Medoxomil_Tab 40mg',
#     'nic': 52.52,
#     'act_cost': 49.08,
#     'quantity': 84,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0205052C0AAAAAA',
#     'items': 9,
#     'practice': 'A81017',
#     'bnf_name': 'Candesartan Cilexetil_Tab 2mg',
#     'nic': 81.0,
#     'act_cost': 75.09,
#     'quantity': 252,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0205052C0AAABAB',
#     'items': 16,
#     'practice': 'A81017',
#     'bnf_name': 'Candesartan Cilexetil_Tab 4mg',
#     'nic': 43.56,
#     'act_cost': 40.52,
#     'quantity': 462,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0205052C0AAACAC',
#     'items': 39,
#     'practice': 'A81017',
#     'bnf_name': 'Candesartan Cilexetil_Tab 8mg',
#     'nic': 43.12,
#     'act_cost': 40.42,
#     'quantity': 1232,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0205052C0AAADAD',
#     'items': 28,
#     'practice': 'A81017',
#     'bnf_name': 'Candesartan Cilexetil_Tab 16mg',
#     'nic': 35.65,
#     'act_cost': 33.33,
#     'quantity': 868,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0205052C0AAAHAH',
#     'items': 14,
#     'practice': 'A81017',
#     'bnf_name': 'Candesartan Cilexetil_Tab 32mg',
#     'nic': 12.74,
#     'act_cost': 12.76,
#     'quantity': 224,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0205052I0AAAAAA',
#     'items': 4,
#     'practice': 'A81017',
#     'bnf_name': 'Irbesartan_Tab 75mg',
#     'nic': 7.76,
#     'act_cost': 7.23,
#     'quantity': 224,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0205052I0AAABAB',
#     'items': 9,
#     'practice': 'A81017',
#     'bnf_name': 'Irbesartan_Tab 150mg',
#     'nic': 33.21,
#     'act_cost': 30.85,
#     'quantity': 308,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0205052I0AAACAC',
#     'items': 18,
#     'practice': 'A81017',
#     'bnf_name': 'Irbesartan_Tab 300mg',
#     'nic': 39.12,
#     'act_cost': 36.43,
#     'quantity': 672,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0205052N0AAAAAA',
#     'items': 65,
#     'practice': 'A81017',
#     'bnf_name': 'Losartan Pot_Tab 25mg',
#     'nic': 53.8,
#     'act_cost': 51.49,
#     'quantity': 1883,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0205052N0AAABAB',
#     'items': 140,
#     'practice': 'A81017',
#     'bnf_name': 'Losartan Pot_Tab 50mg',
#     'nic': 125.22,
#     'act_cost': 119.44,
#     'quantity': 4074,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0205052N0AAADAD',
#     'items': 118,
#     'practice': 'A81017',
#     'bnf_name': 'Losartan Pot_Tab 100mg',
#     'nic': 165.05,
#     'act_cost': 156.37,
#     'quantity': 2994,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0205052N0AAAHAH',
#     'items': 2,
#     'practice': 'A81017',
#     'bnf_name': 'Losartan Pot_Tab 12.5mg',
#     'nic': 79.98,
#     'act_cost': 74.06,
#     'quantity': 84,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0205052P0AAAAAA',
#     'items': 1,
#     'practice': 'A81017',
#     'bnf_name': 'Losartan Pot/Hydchloroth_Tab 50mg/12.5mg',
#     'nic': 2.62,
#     'act_cost': 2.44,
#     'quantity': 56,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0205052P0AAABAB',
#     'items': 2,
#     'practice': 'A81017',
#     'bnf_name': 'Losartan Pot/Hydchloroth_Tab 100mg/25mg',
#     'nic': 3.1,
#     'act_cost': 2.9,
#     'quantity': 56,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0205052Q0AAABAB',
#     'items': 2,
#     'practice': 'A81017',
#     'bnf_name': 'Telmisartan_Tab 80mg',
#     'nic': 5.84,
#     'act_cost': 5.43,
#     'quantity': 112,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0205052R0AAABAB',
#     'items': 1,
#     'practice': 'A81017',
#     'bnf_name': 'Telmisartan/Hydchloroth_Tab 80mg/12.5mg',
#     'nic': 17.0,
#     'act_cost': 15.75,
#     'quantity': 28,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0205052V0AAAAAA',
#     'items': 3,
#     'practice': 'A81017',
#     'bnf_name': 'Valsartan_Cap 40mg',
#     'nic': 33.04,
#     'act_cost': 30.62,
#     'quantity': 196,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0205052V0AAACAC',
#     'items': 2,
#     'practice': 'A81017',
#     'bnf_name': 'Valsartan_Cap 160mg',
#     'nic': 15.6,
#     'act_cost': 14.47,
#     'quantity': 84,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0205052W0AAACAC',
#     'items': 1,
#     'practice': 'A81017',
#     'bnf_name': 'Eprosartan_Tab 600mg',
#     'nic': 13.67,
#     'act_cost': 12.67,
#     'quantity': 28,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0206010F0AAAHAH',
#     'items': 3,
#     'practice': 'A81017',
#     'bnf_name': 'Glyceryl Trinit_Tab 500mcg',
#     'nic': 22.92,
#     'act_cost': 21.26,
#     'quantity': 400,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0206010F0AAA5A5',
#     'items': 1,
#     'practice': 'A81017',
#     'bnf_name': 'Glyceryl Trinit_Tab 300mcg',
#     'nic': 2.3,
#     'act_cost': 2.14,
#     'quantity': 100,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0206010F0AACGCG',
#     'items': 75,
#     'practice': 'A81017',
#     'bnf_name': 'Glyceryl Trinit_Sub A/Spy 400mcg (180D)',
#     'nic': 237.93,
#     'act_cost': 221.16,
#     'quantity': 77,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0206010F0AACICI',
#     'items': 42,
#     'practice': 'A81017',
#     'bnf_name': 'Glyceryl Trinit_Sub P/Spy 400mcg (180D)',
#     'nic': 75.18,
#     'act_cost': 70.14,
#     'quantity': 42,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0206010F0BKAABH',
#     'items': 2,
#     'practice': 'A81017',
#     'bnf_name': 'Transiderm-Nitro 5_Patch',
#     'nic': 81.84,
#     'act_cost': 75.79,
#     'quantity': 112,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0206010I0AAAEAE',
#     'items': 3,
#     'practice': 'A81017',
#     'bnf_name': 'Isosorbide Dinit_Tab 20mg',
#     'nic': 43.14,
#     'act_cost': 39.97,
#     'quantity': 168,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0206010K0AAABAB',
#     'items': 60,
#     'practice': 'A81017',
#     'bnf_name': 'Isosorbide Mononit_Tab 10mg',
#     'nic': 191.25,
#     'act_cost': 178.92,
#     'quantity': 3150,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0206010K0AAACAC',
#     'items': 36,
#     'practice': 'A81017',
#     'bnf_name': 'Isosorbide Mononit_Tab 20mg',
#     'nic': 115.05,
#     'act_cost': 108.46,
#     'quantity': 1890,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0206010K0AAADAD',
#     'items': 3,
#     'practice': 'A81017',
#     'bnf_name': 'Isosorbide Mononit_Tab 40mg',
#     'nic': 6.57,
#     'act_cost': 6.12,
#     'quantity': 168,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0206010K0AAAEAE',
#     'items': 8,
#     'practice': 'A81017',
#     'bnf_name': 'Isosorbide Mononit_Tab 60mg M/R',
#     'nic': 110.25,
#     'act_cost': 102.26,
#     'quantity': 294,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0206010K0AAAFAF',
#     'items': 9,
#     'practice': 'A81017',
#     'bnf_name': 'Isosorbide Mononit_Cap 50mg M/R',
#     'nic': 25.82,
#     'act_cost': 24.42,
#     'quantity': 196,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0206010K0AAAHAH',
#     'items': 3,
#     'practice': 'A81017',
#     'bnf_name': 'Isosorbide Mononit_Cap 25mg M/R',
#     'nic': 10.2,
#     'act_cost': 9.48,
#     'quantity': 84,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0206010K0AAAPAP',
#     'items': 6,
#     'practice': 'A81017',
#     'bnf_name': 'Isosorbide Mononit_Cap 40mg M/R',
#     'nic': 19.56,
#     'act_cost': 18.59,
#     'quantity': 84,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0206010K0AAAQAQ',
#     'items': 3,
#     'practice': 'A81017',
#     'bnf_name': 'Isosorbide Mononit_Cap 60mg M/R',
#     'nic': 26.58,
#     'act_cost': 24.64,
#     'quantity': 84,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0206020A0AAAAAA',
#     'items': 511,
#     'practice': 'A81017',
#     'bnf_name': 'Amlodipine_Tab 5mg',
#     'nic': 391.38,
#     'act_cost': 372.27,
#     'quantity': 15131,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0206020A0AAABAB',
#     'items': 444,
#     'practice': 'A81017',
#     'bnf_name': 'Amlodipine_Tab 10mg',
#     'nic': 370.4,
#     'act_cost': 352.41,
#     'quantity': 13069,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0206020C0AAAAAA',
#     'items': 18,
#     'practice': 'A81017',
#     'bnf_name': 'Diltiazem HCl_Tab 60mg M/R',
#     'nic': 430.72,
#     'act_cost': 400.26,
#     'quantity': 870,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0206020C0BFACAT',
#     'items': 2,
#     'practice': 'A81017',
#     'bnf_name': 'Adizem-SR_Cap 90mg',
#     'nic': 17.0,
#     'act_cost': 15.76,
#     'quantity': 112,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0206020C0BFADAU',
#     'items': 4,
#     'practice': 'A81017',
#     'bnf_name': 'Adizem-SR_Cap 120mg',
#     'nic': 42.53,
#     'act_cost': 39.52,
#     'quantity': 252,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0206020C0BFAEAV',
#     'items': 2,
#     'practice': 'A81017',
#     'bnf_name': 'Adizem-SR_Cap 180mg',
#     'nic': 14.16,
#     'act_cost': 13.34,
#     'quantity': 56,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0206020C0BFAFAE',
#     'items': 5,
#     'practice': 'A81017',
#     'bnf_name': 'Adizem-XL_Cap 300mg',
#     'nic': 63.98,
#     'act_cost': 59.29,
#     'quantity': 196,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0206020C0BFAGAU',
#     'items': 6,
#     'practice': 'A81017',
#     'bnf_name': 'Adizem-XL_Cap 120mg',
#     'nic': 54.84,
#     'act_cost': 50.83,
#     'quantity': 168,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0206020C0BFAHAV',
#     'items': 9,
#     'practice': 'A81017',
#     'bnf_name': 'Adizem-XL_Cap 180mg',
#     'nic': 72.58,
#     'act_cost': 67.69,
#     'quantity': 196,
#     'post_code': 'TS17 0EE'},
#    {'bnf_code': '0206020C0BFAIAW',
#     'items': 10,
#     'practice': 'A81017',
#     'bnf_name': 'Adizem-XL_Cap 240mg',
#     'nic': 115.2,
#     'act_cost': 106.78,
#     'quantity': 280,
#     'post_code': 'TS17 0EE'},
# ...
#     'bnf_name': 'Bard Biocath Aquamatic H/Gel Foy P-Fill',
#     'nic': 34.4,
#     'act_cost': 31.85,
#     'quantity': 4,
#     'post_code': 'HA3 7LT'},
#    {'bnf_code': '21070410110',
#     'items': 2,
#     'practice': 'E84004',
#     'bnf_name': 'Class 1 Stnd C/Kt B/Knee Stkn Elas Hose',
#     'nic': 22.56,
#     'act_cost': 20.91,
#     'quantity': 6,
#     'post_code': 'HA3 7LT'},
#    {'bnf_code': '21070410120',
#     'items': 1,
#     'practice': 'E84004',
#     'bnf_name': 'Class 1 Stnd C/Kt Thigh Stkn Elas Hose',
#     'nic': 16.48,
#     'act_cost': 15.27,
#     'quantity': 4,
#     'post_code': 'HA3 7LT'},
#    {'bnf_code': '21070510130',
#     'items': 3,
#     'practice': 'E84004',
#     'bnf_name': 'Class 11 Stnd C/Kt B/Knee Stkn Elas Hose',
#     'nic': 55.0,
#     'act_cost': 50.96,
#     'quantity': 10,
#     'post_code': 'HA3 7LT'},
#    {'bnf_code': '21120000161',
#     'items': 1,
#     'practice': 'E84004',
#     'bnf_name': 'Medicareplus Stnd Range Peak Flow Meter',
#     'nic': 4.5,
#     'act_cost': 4.18,
#     'quantity': 1,
#     'post_code': 'HA3 7LT'},
#    {'bnf_code': '21120000162',
#     'items': 2,
#     'practice': 'E84004',
#     'bnf_name': 'Medicareplus Low Range Peak Flow Meter H',
#     'nic': 13.0,
#     'act_cost': 12.06,
#     'quantity': 2,
#     'post_code': 'HA3 7LT'},
#    {'bnf_code': '21130000104',
#     'items': 1,
#     'practice': 'E84004',
#     'bnf_name': 'Optiflo S Cath Maint Soln 50ml',
#     'nic': 13.56,
#     'act_cost': 12.55,
#     'quantity': 4,
#     'post_code': 'HA3 7LT'},
#    {'bnf_code': '21160000060',
#     'items': 2,
#     'practice': 'E84004',
#     'bnf_name': 'Irripod Sod Chlor Top Irrig 20ml',
#     'nic': 11.68,
#     'act_cost': 10.84,
#     'quantity': 50,
#     'post_code': 'HA3 7LT'},
#    {'bnf_code': '21210000005',
#     'items': 1,
#     'practice': 'E84004',
#     'bnf_name': 'Biotene Oralbalance Gel',
#     'nic': 4.46,
#     'act_cost': 4.14,
#     'quantity': 50,
#     'post_code': 'HA3 7LT'},
#    {'bnf_code': '21220000100',
#     'items': 3,
#     'practice': 'E84004',
#     'bnf_name': 'Epaderm Oint',
#     'nic': 26.12,
#     'act_cost': 24.22,
#     'quantity': 2000,
#     'post_code': 'HA3 7LT'},
#    {'bnf_code': '21220000101',
#     'items': 5,
#     'practice': 'E84004',
#     'bnf_name': 'Epaderm Crm',
#     'nic': 41.7,
#     'act_cost': 38.67,
#     'quantity': 3000,
#     'post_code': 'HA3 7LT'},
#    {'bnf_code': '21220000111',
#     'items': 1,
#     'practice': 'E84004',
#     'bnf_name': 'Flexitol Urea Heel Balm',
#     'nic': 3.8,
#     'act_cost': 3.53,
#     'quantity': 75,
#     'post_code': 'HA3 7LT'},
#    {'bnf_code': '21220000205',
#     'items': 7,
#     'practice': 'E84004',
#     'bnf_name': 'Hydromol Oint',
#     'nic': 40.86,
#     'act_cost': 37.91,
#     'quantity': 3500,
#     'post_code': 'HA3 7LT'},
#    {'bnf_code': '21220000210',
#     'items': 1,
#     'practice': 'E84004',
#     'bnf_name': 'QV Crm',
#     'nic': 11.84,
#     'act_cost': 10.97,
#     'quantity': 1000,
#     'post_code': 'HA3 7LT'},
#    {'bnf_code': '21220000212',
#     'items': 1,
#     'practice': 'E84004',
#     'bnf_name': 'QV Intensive Oint',
#     'nic': 5.71,
#     'act_cost': 5.3,
#     'quantity': 450,
#     'post_code': 'HA3 7LT'},
#    {'bnf_code': '21220000214',
#     'items': 1,
#     'practice': 'E84004',
#     'bnf_name': 'Zerobase Crm (Appl)',
#     'nic': 5.26,
#     'act_cost': 4.88,
#     'quantity': 500,
#     'post_code': 'HA3 7LT'},
#    {'bnf_code': '21220000215',
#     'items': 3,
#     'practice': 'E84004',
#     'bnf_name': 'Zerocream (Appl)',
#     'nic': 20.4,
#     'act_cost': 18.92,
#     'quantity': 2500,
#     'post_code': 'HA3 7LT'},
#    {'bnf_code': '21220000218',
#     'items': 20,
#     'practice': 'E84004',
#     'bnf_name': 'ZeroAQS Crm',
#     'nic': 78.96,
#     'act_cost': 73.35,
#     'quantity': 12000,
#     'post_code': 'HA3 7LT'},
#    {'bnf_code': '21220000229',
#     'items': 9,
#     'practice': 'E84004',
#     'bnf_name': 'LPL 63.4 Bath Add and Emollient',
#     'nic': 27.9,
#     'act_cost': 25.94,
#     'quantity': 4500,
#     'post_code': 'HA3 7LT'},
#    {'bnf_code': '21220000233',
#     'items': 1,
#     'practice': 'E84004',
#     'bnf_name': 'Cetraben Crm 50g',
#     'nic': 28.0,
#     'act_cost': 25.93,
#     'quantity': 20,
#     'post_code': 'HA3 7LT'},
#    {'bnf_code': '21220000235',
#     'items': 8,
#     'practice': 'E84004',
#     'bnf_name': 'Cetraben Crm 500g',
#     'nic': 65.89,
#     'act_cost': 61.1,
#     'quantity': 11,
#     'post_code': 'HA3 7LT'},
#    {'bnf_code': '21220000242',
#     'items': 3,
#     'practice': 'E84004',
#     'bnf_name': 'Epimax Crm 500g',
#     'nic': 7.47,
#     'act_cost': 6.96,
#     'quantity': 1500,
#     'post_code': 'HA3 7LT'},
#    {'bnf_code': '21230000105',
#     'items': 1,
#     'practice': 'E84004',
#     'bnf_name': 'ReplensMD Vag Moist 35g Tube',
#     'nic': 6.06,
#     'act_cost': 5.62,
#     'quantity': 1,
#     'post_code': 'HA3 7LT'},
#    {'bnf_code': '21240000100',
#     'items': 3,
#     'practice': 'E84004',
#     'bnf_name': 'Orbis Nor Saline Sod Chlor 0.9% Nsl Dps',
#     'nic': 2.85,
#     'act_cost': 2.68,
#     'quantity': 3,
#     'post_code': 'HA3 7LT'},
#    {'bnf_code': '21240000120',
#     'items': 3,
#     'practice': 'E84004',
#     'bnf_name': 'Almus Sod Chlor 0.9% Nsl Dps',
#     'nic': 2.97,
#     'act_cost': 2.79,
#     'quantity': 3,
#     'post_code': 'HA3 7LT'},
#    {'bnf_code': '21300000104',
#     'items': 14,
#     'practice': 'E84004',
#     'bnf_name': 'Hylo-Tear Sod Hyaluronate Eye Dps 0.1% P',
#     'nic': 178.5,
#     'act_cost': 165.42,
#     'quantity': 21,
#     'post_code': 'HA3 7LT'},
#    {'bnf_code': '21300000108',
#     'items': 1,
#     'practice': 'E84004',
#     'bnf_name': 'Hyabak Sod Hyaluronate Eye Dps 10ml P/F',
#     'nic': 7.99,
#     'act_cost': 7.41,
#     'quantity': 1,
#     'post_code': 'HA3 7LT'},
#    {'bnf_code': '21300000110',
#     'items': 3,
#     'practice': 'E84004',
#     'bnf_name': 'Systane Hydroxypropyl Guar Eye Dps 10ml',
#     'nic': 18.64,
#     'act_cost': 17.29,
#     'quantity': 4,
#     'post_code': 'HA3 7LT'},
#    {'bnf_code': '21300000111',
#     'items': 4,
#     'practice': 'E84004',
#     'bnf_name': 'Hylo-Forte Sod Hyaluronate Eye Dps 0.2%',
#     'nic': 47.5,
#     'act_cost': 44.03,
#     'quantity': 5,
#     'post_code': 'HA3 7LT'},
#    {'bnf_code': '21300000113',
#     'items': 1,
#     'practice': 'E84004',
#     'bnf_name': 'Hylo-Fresh Sod Hyaluronate Eye Dps P/F 1',
#     'nic': 4.95,
#     'act_cost': 4.59,
#     'quantity': 1,
#     'post_code': 'HA3 7LT'},
#    {'bnf_code': '21300000123',
#     'items': 5,
#     'practice': 'E84004',
#     'bnf_name': 'Alissa Carmellose 0.5% Eye Dps 10ml',
#     'nic': 44.94,
#     'act_cost': 41.67,
#     'quantity': 6,
#     'post_code': 'HA3 7LT'},
#    {'bnf_code': '21300000143',
#     'items': 2,
#     'practice': 'E84004',
#     'bnf_name': 'Systane Gel Dps Hydroxypropyl Guar Eye D',
#     'nic': 22.47,
#     'act_cost': 20.83,
#     'quantity': 30,
#     'post_code': 'HA3 7LT'},
#    {'bnf_code': '21300000171',
#     'items': 4,
#     'practice': 'E84004',
#     'bnf_name': 'Xailin HA Sod Hyaluronate 0.2% Eye Dps 1',
#     'nic': 28.52,
#     'act_cost': 26.46,
#     'quantity': 4,
#     'post_code': 'HA3 7LT'},
#    {'bnf_code': '21300000300',
#     'items': 6,
#     'practice': 'E84004',
#     'bnf_name': 'Optive 0.5% Carmellose Eye Dps 10ml',
#     'nic': 74.9,
#     'act_cost': 69.41,
#     'quantity': 10,
#     'post_code': 'HA3 7LT'},
#    {'bnf_code': '21300000401',
#     'items': 1,
#     'practice': 'E84004',
#     'bnf_name': 'Liquifilm 1.4% Polyvinyl Alcohol Eye Dps',
#     'nic': 3.86,
#     'act_cost': 3.59,
#     'quantity': 2,
#     'post_code': 'HA3 7LT'},
#    {'bnf_code': '21300000403',
#     'items': 1,
#     'practice': 'E84004',
#     'bnf_name': 'Refresh Ophth Polyvinyl Alcohol Eye Dps',
#     'nic': 2.25,
#     'act_cost': 2.1,
#     'quantity': 30,
#     'post_code': 'HA3 7LT'},
#    {'bnf_code': '21300000702',
#     'items': 6,
#     'practice': 'E84004',
#     'bnf_name': 'Clinitas Carbomer Eye Gel',
#     'nic': 13.41,
#     'act_cost': 12.48,
#     'quantity': 90,
#     'post_code': 'HA3 7LT'},
#    {'bnf_code': '21300000710',
#     'items': 10,
#     'practice': 'E84004',
#     'bnf_name': 'Vita-POS Paraf Eye Oint P/F',
#     'nic': 41.25,
#     'act_cost': 38.32,
#     'quantity': 75,
#     'post_code': 'HA3 7LT'},
#    {'bnf_code': '21300000711',
#     'items': 5,
#     'practice': 'E84004',
#     'bnf_name': 'Xailin Night Paraf Eye Oint P/F 5g',
#     'nic': 19.92,
#     'act_cost': 18.51,
#     'quantity': 8,
#     'post_code': 'HA3 7LT'},
#    {'bnf_code': '22601006045',
#     'items': 1,
#     'practice': 'E84004',
#     'bnf_name': 'Coloplast_Simpla Profile Night Bag + 120',
#     'nic': 17.61,
#     'act_cost': 16.3,
#     'quantity': 10,
#     'post_code': 'HA3 7LT'},
#    {'bnf_code': '22605056010',
#     'items': 1,
#     'practice': 'E84004',
#     'bnf_name': 'Unomedical_Careline Easi MT Drain Bag 2L',
#     'nic': 10.05,
#     'act_cost': 9.32,
#     'quantity': 30,
#     'post_code': 'HA3 7LT'},
#    {'bnf_code': '23150701503',
#     'items': 1,
#     'practice': 'E84004',
#     'bnf_name': 'Dansac_Non Sting Adh Remover A/Spy 50ml',
#     'nic': 56.4,
#     'act_cost': 52.21,
#     'quantity': 6,
#     'post_code': 'HA3 7LT'},
#    {'bnf_code': '23150701505',
#     'items': 2,
#     'practice': 'E84004',
#     'bnf_name': 'Dansac_EasiSpray Adh Remover 50ml',
#     'nic': 52.56,
#     'act_cost': 48.65,
#     'quantity': 8,
#     'post_code': 'HA3 7LT'},
#    {'bnf_code': '23350703767',
#     'items': 1,
#     'practice': 'E84004',
#     'bnf_name': 'Dansac_NovaLife 1 Closed Colo Bag Midi O',
#     'nic': 87.3,
#     'act_cost': 80.82,
#     'quantity': 30,
#     'post_code': 'HA3 7LT'},
#    {'bnf_code': '23804808005',
#     'items': 2,
#     'practice': 'E84004',
#     'bnf_name': 'Convatec_Orabase Paste 30g',
#     'nic': 4.28,
#     'act_cost': 3.99,
#     'quantity': 2,
#     'post_code': 'HA3 7LT'},
#    {'bnf_code': '0101021B0AAAPAP',
#     'items': 2,
#     'practice': 'E84069',
#     'bnf_name': 'Sod Alginate/Pot Bicarb_Tab Chble 500mg',
#     'nic': 6.14,
#     'act_cost': 5.71,
#     'quantity': 120,
#     'post_code': 'HA3 7LT'},
#    {'bnf_code': '0101021B0BEADAJ',
#     'items': 4,
#     'practice': 'E84069',
#     'bnf_name': 'Gaviscon Infant_Sach 2g (Dual Pack) S/F',
#     'nic': 67.48,
#     'act_cost': 62.52,
#     'quantity': 210,
#     'post_code': 'HA3 7LT'},
#    {'bnf_code': '0101021B0BEAIAL',
#     'items': 4,
#     'practice': 'E84069',
#     'bnf_name': 'Gaviscon Advance_Liq (Aniseed) (Reckitt)',
#     'nic': 20.99,
#     'act_cost': 19.57,
#     'quantity': 2050,
#     'post_code': 'HA3 7LT'},
#    {'bnf_code': '0101021B0BEAQAP',
#     'items': 1,
#     'practice': 'E84069',
#     'bnf_name': 'Gaviscon Advance_Tab Chble Mint(Reckitt)',
#     'nic': 6.14,
#     'act_cost': 5.7,
#     'quantity': 120,
#     'post_code': 'HA3 7LT'},
#    {'bnf_code': '0101021B0BIAAAH',
#     'items': 6,
#     'practice': 'E84069',
#     'bnf_name': 'Peptac_Liq (Aniseed) S/F',
#     'nic': 11.7,
#     'act_cost': 10.91,
#     'quantity': 3000,
#     'post_code': 'HA3 7LT'},
#    {'bnf_code': '0101021B0BIABAH',
#     'items': 42,
#     'practice': 'E84069',
#     'bnf_name': 'Peptac_Liq (Peppermint) S/F',
#     'nic': 84.63,
#     'act_cost': 79.19,
#     'quantity': 21700,
#     'post_code': 'HA3 7LT'},
#    {'bnf_code': '0102000A0AAABAB',
#     'items': 2,
#     'practice': 'E84069',
#     'bnf_name': 'Alverine Cit_Cap 120mg',
#     'nic': 88.46,
#     'act_cost': 82.01,
#     'quantity': 228,
#     'post_code': 'HA3 7LT'},
#    {'bnf_code': '0102000N0AAABAB',
#     'items': 22,
#     'practice': 'E84069',
#     'bnf_name': 'Hyoscine Butylbrom_Tab 10mg',
#     'nic': 62.58,
#     'act_cost': 59.4,
#     'quantity': 1168,
#     'post_code': 'HA3 7LT'},
#    {'bnf_code': '0102000P0AAABAB',
#     'items': 19,
#     'practice': 'E84069',
#     'bnf_name': 'Mebeverine HCl_Tab 135mg',
#     'nic': 95.6,
#     'act_cost': 89.83,
#     'quantity': 1832,
#     'post_code': 'HA3 7LT'},
#    {'bnf_code': '0102000P0AAADAD',
#     'items': 1,
#     'practice': 'E84069',
#     'bnf_name': 'Mebeverine HCl_Cap 200mg M/R',
#     'nic': 10.38,
#     'act_cost': 9.72,
#     'quantity': 90,
#     'post_code': 'HA3 7LT'},
#    {'bnf_code': '0102000T0AAAAAA',
#     'items': 3,
#     'practice': 'E84069',
#     'bnf_name': 'Peppermint Oil_Cap E/C 0.2ml',
#     'nic': 42.24,
#     'act_cost': 39.14,
#     'quantity': 504,
#     'post_code': 'HA3 7LT'},
#    {'bnf_code': '0103010T0AAAAAA',
#     'items': 33,
#     'practice': 'E84069',
#     'bnf_name': 'Ranitidine HCl_Tab 150mg',
#     'nic': 47.18,
#     'act_cost': 45.1,
#     'quantity': 2282,
#     'post_code': 'HA3 7LT'},
#    {'bnf_code': '0103010T0AAACAC',
#     'items': 5,
#     'practice': 'E84069',
#     'bnf_name': 'Ranitidine HCl_Tab 300mg',
#     'nic': 7.46,
#     'act_cost': 7.16,
#     'quantity': 176,
#     'post_code': 'HA3 7LT'},
#    {'bnf_code': '0103010T0AAAEAE',
#     'items': 1,
#     'practice': 'E84069',
#     'bnf_name': 'Ranitidine HCl_Oral Soln 75mg/5ml S/F',
#     'nic': 2.09,
#     'act_cost': 2.05,
#     'quantity': 100,
#     'post_code': 'HA3 7LT'},
#    {'bnf_code': '0103050E0AAAAAA',
#     'items': 4,
#     'practice': 'E84069',
#     'bnf_name': 'Esomeprazole_Tab E/C 20mg',
#     'nic': 13.25,
#     'act_cost': 12.32,
#     'quantity': 140,
#     'post_code': 'HA3 7LT'},
#    {'bnf_code': '0103050E0AAABAB',
#     'items': 5,
#     'practice': 'E84069',
#     'bnf_name': 'Esomeprazole_Tab E/C 40mg',
#     'nic': 19.86,
#     'act_cost': 18.46,
#     'quantity': 168,
#     'post_code': 'HA3 7LT'},
#    {'bnf_code': '0103050L0AAAAAA',
#     'items': 151,
#     'practice': 'E84069',
#     'bnf_name': 'Lansoprazole_Cap 30mg (E/C Gran)',
#     'nic': 224.23,
#     'act_cost': 209.86,
#     'quantity': 5656,
#     'post_code': 'HA3 7LT'},
#    {'bnf_code': '0103050L0AAABAB',
#     'items': 63,
#     'practice': 'E84069',
#     'bnf_name': 'Lansoprazole_Cap 15mg (E/C Gran)',
#     'nic': 73.08,
#     'act_cost': 68.43,
#     'quantity': 2436,
#     'post_code': 'HA3 7LT'},
#    {'bnf_code': '0103050L0AAAHAH',
#     'items': 3,
#     'practice': 'E84069',
#     'bnf_name': 'Lansoprazole_Orodisper Tab 30mg',
#     'nic': 10.26,
#     'act_cost': 9.54,
#     'quantity': 84,
#     'post_code': 'HA3 7LT'},
#    {'bnf_code': '0103050P0AAAAAA',
#     'items': 395,
#     'practice': 'E84069',
#     'bnf_name': 'Omeprazole_Cap E/C 20mg',
#     'nic': 547.66,
#     'act_cost': 512.7,
#     'quantity': 16850,
#     'post_code': 'HA3 7LT'},
#    {'bnf_code': '0103050P0AAAEAE',
#     'items': 1,
#     'practice': 'E84069',
#     'bnf_name': 'Omeprazole_Cap E/C 40mg',
#     'nic': 3.0,
#     'act_cost': 2.79,
#     'quantity': 28,
#     'post_code': 'HA3 7LT'},
#    {'bnf_code': '0103050P0AAAFAF',
#     'items': 14,
#     'practice': 'E84069',
#     'bnf_name': 'Omeprazole_Cap E/C 10mg',
#     'nic': 12.36,
#     'act_cost': 12.02,
#     'quantity': 389,
#     'post_code': 'HA3 7LT'},
#    {'bnf_code': '0103050P0AAAMAM',
#     'items': 1,
#     'practice': 'E84069',
#     'bnf_name': 'Omeprazole_Tab Disper 10mg (E/C Pellets)',
#     'nic': 7.75,
#     'act_cost': 7.19,
#     'quantity': 28,
#     'post_code': 'HA3 7LT'},
#    {'bnf_code': '0103050P0AAANAN',
#     'items': 1,
#     'practice': 'E84069',
#     'bnf_name': 'Omeprazole_Tab Disper 20mg (E/C Pellets)',
#     'nic': 23.2,
#     'act_cost': 21.49,
#     'quantity': 56,
#     'post_code': 'HA3 7LT'},
#    {'bnf_code': '0103050P0AABDBD',
#     'items': 1,
#     'practice': 'E84069',
#     'bnf_name': 'Omeprazole_Tab E/C 20mg',
#     'nic': 12.02,
#     'act_cost': 11.14,
#     'quantity': 56,
#     'post_code': 'HA3 7LT'},
#    {'bnf_code': '0103050R0AAAAAA',
#     'items': 8,
#     'practice': 'E84069',
#     'bnf_name': 'Pantoprazole_Tab E/C 40mg',
#     'nic': 14.56,
#     'act_cost': 13.59,
#     'quantity': 364,
#     'post_code': 'HA3 7LT'},
#    {'bnf_code': '0103050R0AAABAB',
#     'items': 2,
#     'practice': 'E84069',
#     'bnf_name': 'Pantoprazole_Tab E/C 20mg',
#     'nic': 1.9,
#     'act_cost': 1.78,
#     'quantity': 56,
#     'post_code': 'HA3 7LT'},
#    {'bnf_code': '0103050T0AAAAAA',
#     'items': 1,
#     'practice': 'E84069',
#     'bnf_name': 'Rabeprazole Sod_Tab E/C 10mg',
#     'nic': 5.36,
#     'act_cost': 4.97,
#     'quantity': 112,
#     'post_code': 'HA3 7LT'},
#    {'bnf_code': '0103050T0AAABAB',
#     'items': 2,
#     'practice': 'E84069',
#     'bnf_name': 'Rabeprazole Sod_Tab E/C 20mg',
#     'nic': 3.54,
#     'act_cost': 3.3,
#     'quantity': 56,
#     'post_code': 'HA3 7LT'},
#    {'bnf_code': '0104020L0AAAAAA',
#     'items': 19,
#     'practice': 'E84069',
#     'bnf_name': 'Loperamide HCl_Cap 2mg',
#     'nic': 74.53,
#     'act_cost': 70.04,
#     'quantity': 2329,
#     'post_code': 'HA3 7LT'},
#    ...])]

# %%
postal_totals = items_by_post[:100]

grader.score.pw__postal_totals(postal_totals)
# Out:
# ==================
# Your score:  1.0
# ==================

# %% [markdown]
# ## Question 4: items_by_region
#
# Now we'll combine the techniques we've developed to answer a more complex question. Find the most commonly dispensed item in each postal code, representing the results as a list of tuples (`post_code`, `bnf_name`, amount dispensed as proportion of total). Sort your results ascending alphabetically by post code and take only results from the first 100 post codes.
#
# **NOTE:** We'll continue to use the `joined` variable we created before, where we've chosen the alphabetically first postal code for each practice. Additionally, some postal codes will have multiple `'bnf_name'` with the same number of items prescribed for the maximum. In this case, we'll take the alphabetically first `'bnf_name'`.

# %% [markdown]
# Now we need to calculate the total items of each `'bnf_name'` prescribed in each `'post_code'`. Use the techniques we developed in the previous questions to calculate these totals. You should have 141196 `('post_code', 'bnf_name')` groups.

# %%
name_grouped = group_by_field(joined, ('post_code','bnf_name')).items()
total_items_by_bnf_post= {name: sum(group['items'] for group in groups) for name, groups in name_grouped}
assert len(total_items_by_bnf_post) == 141196

# %% [markdown]
# Let's use `total_items` to find the maximum item total for each postal code. To do this, we will want to regroup `total_items_by_bnf_post` by `'post_code'` only, not by `('post_code', 'bnf_name')`. First let's turn `total_items` into a list of dictionaries (similar to `scripts` or `practices`) and then group it by `'post_code'`. You should have 118 groups in the resulting `total_items_by_post` after grouping `total_items` by `'post_code'`.

# %%
total_items= [{'post_code': tup[0], 'bnf_name': tup[1], 'total' : tot} for tup, tot in list(total_items_by_bnf_post.items())]

total_items_by_post = group_by_field(total_items, ('post_code',))


assert len(total_items_by_post) == 118

# %% [markdown]
# Now we will aggregate the groups in `total_by_item_post` to create `max_item_by_post`. Some `'bnf_name'` have the same item total within a given postal code. Therefore, if more than one `'bnf_name'` has the maximum item total in a given postal code, we'll take the alphabetically first `'bnf_name'`. We can do this by [sorting](https://docs.python.org/2.7/howto/sorting.html) each group according to the item total and `'bnf_name'`.

# %%
max_items_by_post = [sorted(group, key=lambda mem: (-mem['total'], mem['bnf_name']))[0] for group in total_items_by_post.values()]

# %% [markdown]
# In order to express the item totals as a proportion of the total amount of items prescribed across all `'bnf_name'` in a postal code, we'll need to use the total items prescribed that we previously calculated as `items_by_post`. Calculate the proportions for the most common `'bnf_names'` for each postal code. Format your answer as a list of tuples: `[(post_code, bnf_name, total)]`

# %%
#items_by_region = [('B11 4BW', 'Salbutamol_Inha 100mcg (200 D) CFF', 0.0341508247)] * 100
result= [(item['post_code'], item['bnf_name'],item['total'] /dict(items_by_post)[item['post_code']]) for item in max_items_by_post]

# %%
items_by_region = sorted(result)[:100]

# %%
grader.score.pw__items_by_region(items_by_region)
# Out:
# ==================
# Your score:  1.0
# ==================

# %% [markdown]
# *Copyright &copy; 2020 The Data Incubator.  All rights reserved.*
